# %% [markdown]
# Lists
# A list is an ordered, dunamic collection of data elements that can be modified after created using zero-based indices.
#
# Lists store elements in a sequences, allowing for the addition or removal or items and can hold elements of mixed or single data types.
#
# Indexing:
# - Lists can be indexed using positive or negative numebrs
#
# Index: 0, 1, 2, 3, 4, 5, 6, 7
# value: 9, 4, 2, 9, 6, 7, 8, 34
# Index: -1, -2, -3, -4, -5, -6
#
# 1. establish a list,
# 2. Call the list by (list name[index(positive index/negative index)])
#
# Stacks, queses, binary trees

# %% [markdown]
# List:
# Listing
# Indexing
# Tokenization
# Recalling string
# Slicing
#
# Indexing
# list.index(x[, start[, end]]) : Returns zero-based index of the first occurance of the x in the list.
# 1. Raises a ValueError if there is no such intem

# %%
Fruits = ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'banana']

Fruits.count('tangerine') # Gives the total number of values with the valye tangerine 

Fruits.index('banana') # Calls for the index number of the variable tangerine within the list 

Fruits.append('grape') # Adds the value grape to the end of the list

# %% [markdown]
# Write a program of where to write a list
#
# Reverse listing code:
#
# Store the marks of a student for five subjects as a list:

# %%
Marks = [85, 90, 78, 92, 88] # List of marks for five subjects

Marks1 = input("Please enter the marks for subject 1: ")
Marks2 = input("Please enter the marks for subject 2: ")
Marks3 = input("Please enter the marks for subject 3: ")
Marks4 = input("Please enter the marks for subject 4: ")
Marks5 = input("Please enter the marks for subject 5: ")

Marks = [Marks1, Marks2, Marks3, Marks4, Marks5] 

print(Marks)
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
